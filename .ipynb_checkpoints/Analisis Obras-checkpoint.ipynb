# %% [markdown]
# # Programa Mujeres en Data Science
#
# Llego la hora de poner de comenzar a explorar el dataset para el proyecto de este curso. El objetivo de esta clase es que comiencen a explorar el dataset. La exploración del dataset permitira que puedan hacerse preguntas que puedan ser contestadas con el mismo.

# %%
#importo solo pyplot

import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from datetime import datetime
import pandas as pd
import numpy as np

# %%
#Importo el archivi
obras = pd.read_csv ('observatorio-de-obras-urbanas.csv', delimiter = ",", parse_dates= ["fecha_fin_inicial"])

# %%
#Veo qué forma tiene el df

obras.shape
# Out:
# (991, 36)

# %%
# y cómo son las primeras filas
obras.head()
# Out:
#    id                 entorno  \
# 0   1        Plan 54 escuelas
# 1   2         Donado Holmberg
# 2   3  Area Ambiental Central
# 3   4  Area Ambiental Central
# 4   5          Villa Olímpica
#
#                                               nombre       etapa  \
# 0  Escuela de Educación Primaria N.° 24 D.E. 15 «...  Finalizada
# 1                Calle Holmberg: Nivelacion en cruce  Finalizada
# 2     Area Ambiental Central: Calles Alsina Y Moreno  Finalizada
# 3          Area Ambiental Central: Calle Esmeralda I  Finalizada
# 4  Villa Olímpica: Demoliciones en el Parque de l...  Finalizada
#
#               tipo                              area_responsable  \
# 0         Escuelas          Ministerio de Educación e Innovación
# 1  Espacio Público  Ministerio de Desarrollo Urbano y Transporte
# 2  Espacio Público  Ministerio de Desarrollo Urbano y Transporte
# 3  Espacio Público  Ministerio de Desarrollo Urbano y Transporte
# 4         Vivienda  Ministerio de Desarrollo Urbano y Transporte
#
#                                          descripcion  monto_contrato  comuna  \
# 0                                           Primaria      67065700.0    12.0
# 1  En el marco del proyecto urbano del Barrio Par...       9950017.0    12.0
# 2  Se Intervienen Los Tramos Comprendidos Entre L...      36942632.0     1.0
# 3  La Obra Incluye El Tramo Ubicado Entre La Av. ...      26938294.0     1.0
# 4  Demoliciones de las construcciones existentes ...       6990315.0     8.0
#
#           barrio  ... mano_obra  compromiso  destacada ba_elige  \
# 0  Villa Urquiza  ...       NaN         NaN         SI      NaN
# 1  Villa Urquiza  ...        16         NaN        NaN      NaN
# 2     Montserrat  ...        55          SI        NaN      NaN
# 3    San Nicolás  ...        59          SI        NaN      NaN
# 4  Villa Soldati  ...       NaN          SI        NaN      NaN
#
#                                         link_interno  \
# 0  https://www.buenosaires.gob.ar/baobras/54-escu...
# 1  https://www.buenosaires.gob.ar/baobras/Donado-...
# 2  https://www.buenosaires.gob.ar/baobras/area-am...
# 3  https://www.buenosaires.gob.ar/baobras/area-am...
# 4  https://www.buenosaires.gob.ar/baobras/villa-o...
#
#                                      pliego_descarga     expediente-numero  \
# 0  https://buenosaires.gob.ar/areas/planeamiento_...     914412-MDUGC-2013
# 1  https://www.buenosaires.gov.ar/areas/planeamie...          5515928/2014
# 2  https://www.buenosaires.gov.ar/areas/planeamie...                   NaN
# 3  https://www.buenosaires.gov.ar/areas/planeamie...                   NaN
# 4  https://www.buenosaires.gov.ar/areas/planeamie...  13793268/DGPUYA/2014
#
#   estudio_ambiental_descarga financiamiento     año
# 0                        NaN            NaN  2016.0
# 1                        NaN            NaN  2016.0
# 2                        NaN            NaN  2017.0
# 3                        NaN            NaN  2017.0
# 4                        NaN            NaN  2015.0
#
# [5 rows x 37 columns]

# %%
obras["fecha_fin_inicial"]
# Out:
# 0     2016-05-31
# 1     2016-07-15
# 2     2017-11-15
# 3     2017-02-28
# 4     2015-12-20
# 5     2017-08-30
# 6     2017-10-15
# 7     2017-08-30
# 8     2018-02-15
# 9     2017-09-30
# 10    2017-08-30
# 11    2017-10-31
# 12    2017-11-15
# 13    2017-12-31
# 14    2017-12-20
# 15    2017-03-30
# 16    2018-04-16
# 17    2017-12-31
# 18    2018-12-01
# 19    2018-10-30
# 20    2018-06-30
# 21    2017-01-11
# 22    2018-03-01
# 23    2017-06-30
# 24    2018-06-30
# 25    2018-05-30
# 26    2017-11-15
# 27    2018-01-31
# 28    2019-08-30
# 29    2019-04-30
#          ...
# 961   2019-03-30
# 962   2018-08-01
# 963   2019-05-30
# 964   2019-05-12
# 965   2019-05-30
# 966   2019-01-20
# 967   2016-10-30
# 968   2016-10-30
# 969   2019-02-28
# 970   2019-02-28
# 971   2019-02-28
# 972   2018-12-31
# 973   2018-12-31
# 974   2018-09-28
# 975   2019-07-02
# 976   2018-11-21
# 977   2019-08-15
# 978   2019-05-09
# 979   2019-09-15
# 980          NaT
# 981   2019-06-10
# 982   2019-11-07
# 983   2019-11-13
# 984   2020-02-15
# 985   2019-04-12
# 986   2020-04-27
# 987   2019-08-31
# 988   2020-04-27
# 989   2020-03-02
# 990   2019-06-21
# Name: fecha_fin_inicial, Length: 991, dtype: datetime64[ns]

# %%
print("\n\n\n\n                                             DATOS FALTANTES  \n\n\n  ")

#cantidad de datos nulos en cada columna 


obras.isnull().sum()
# Out:
#                                              DATOS FALTANTES
# id                              0
# entorno                         2
# nombre                          0
# etapa                           0
# tipo                            0
# area_responsable                0
# descripcion                     5
# monto_contrato                103
# comuna                          2
# barrio                          4
# direccion                      64
# lat                             2
# lng                             2
# fecha_inicio                   42
# fecha_fin_inicial              22
# plazo_meses                    93
# porcentaje_avance               2
# imagen_1                       36
# imagen_2                      431
# imagen_3                      621
# imagen_4                      757
# licitacion_oferta_empresa     130
# licitacion_anio               334
# contratacion_tipo             791
# nro_contratacion              793
# cuit_contratista              237
# beneficiarios                 802
# mano_obra                     740
# compromiso                    673
# destacada                     958
# ba_elige                      986
# link_interno                   16
# pliego_descarga               447
# expediente-numero             869
# estudio_ambiental_descarga    943
# financiamiento                985
# año                            22
# dtype: int64

# %%
print(" \n\n\n\n                                          LAS COLUMNAS QUE NOS INTERESAN \n\n\n ")
# Out:
#
#
#
#
#                                           LAS COLUMNAS QUE NOS INTERESAN

# %%
obras.drop(["direccion", "imagen_1", "imagen_2", "imagen_3", "imagen_4", "contratacion_tipo", "nro_contratacion", "beneficiarios", "mano_obra", "compromiso", "destacada", "ba_elige", "link_interno", "pliego_descarga", "expediente-numero", "estudio_ambiental_descarga", "financiamiento"], axis=1)
# 961  Barrio Rodrigo Bueno Etapa 2. 564 Viviendas, 5...    1.624752e+09
# 962  Barrio Rodrigo Bueno Etapa 2. 564 Viviendas, 5...             NaN
# 963  Barrio Rodrigo Bueno Etapa 2. 564 Viviendas, 5...             NaN
# 964  Construcción de un nuevo edificio para alojar ...    7.568221e+07
# 965  La obra a realizar consiste en la demolición t...    1.300119e+07
# 966                                            Inicial             NaN
# 967                                            Inicial             NaN
# 968                                              Media             NaN
# 969                                            Inicial             NaN
# 970                                           Primaria             NaN
# 971                                            Adultos             NaN
# 972                                            Inicial             NaN
# 973                                            Adultos             NaN
# 974  Plaza Italia: las intervenciones involucran la...    9.351796e+07
# 975  Constituye un nuevo recinto unificado, conform...    1.243195e+07
# 976  La intervención consistió en la restauración d...    2.820044e+06
# 977  El conjunto edificio complementario, contempla...             NaN
# 978  Todas las instalaciones referentes al bombeo, ...    6.206032e+06
# 979  Las intervenciones proyectadas se basan, princ...    2.844941e+06
# 980  Adecuación edilicia.Tratamiento de fachadas. I...             NaN
# 981  Las intervenciones contemplan parquizacion con...    6.186354e+07
# 982  Renovación del espacio verde público, plantaci...    1.038330e+07
# 983  Destacar el significativo valor urbanístico, p...    1.997075e+07
# 984  Las intervenciones proyectadas se basan, princ...    1.018930e+07
# 985  La intervención proyectada se enmarca dentro d...    7.709334e+06
# 986  Las intervenciones proyectadas se basan en la ...    2.095802e+07
# 987  Generación de un espacio público, emplazado en...    5.833279e+07
# 988  En respuesta a la propuesta de BA ELIGE con el...             NaN
# 989  En respuesta a la propuesta de BA ELIGE con el...             NaN
# 990  La obra comprende el conjunto de tareas necesa...             NaN
#
#      comuna             barrio        lat        lng fecha_inicio  \
# 0      12.0      Villa Urquiza -34.567153 -58.479237   01/12/2013
# 1      12.0      Villa Urquiza -34.570533 -58.475614   16/03/2015
# 2       1.0         Montserrat -34.610726 -58.380600   12/01/2016
# 3       1.0        San Nicolás -34.603487 -58.378078   27/10/2014
# 4       8.0      Villa Soldati -34.673242 -58.458544   20/12/2014
# 5       8.0       Villa Lugano -34.673748 -58.459004   15/02/2016
# 6       8.0       Villa Lugano -34.673748 -58.459004   25/02/2016
# 7       8.0       Villa Lugano -34.673748 -58.459004   15/02/2016
# 8       8.0       Villa Lugano -34.673748 -58.459004   28/03/2016
# 9       8.0       Villa Lugano -34.673748 -58.459004   15/03/2016
# 10      8.0       Villa Lugano -34.673748 -58.459004   15/02/2016
# 11      8.0       Villa Lugano -34.673748 -58.459004   25/02/2016
# 12      8.0       Villa Lugano -34.673748 -58.459004   15/02/2016
# 13      8.0       Villa Lugano -34.673748 -58.459004   28/04/2016
# 14      8.0       Villa Lugano -34.673748 -58.459004   01/06/2015
# 15      8.0      Villa Soldati -34.673897 -58.436060   28/12/2016
# 16      8.0      Villa Soldati -34.673897 -58.436060   30/01/2017
# 17      8.0      Villa Soldati -34.673897 -58.436060   15/02/2017
# 18      8.0      Villa Soldati -34.673897 -58.436060   15/02/2017
# 22                         Urban Baires S.A.           2016.0
# 23                                 Ucsa S.A.           2016.0
# 24                                Criba S.A.           2017.0
# 25                         Urban Baires S.A.           2016.0
# 26                                Cunumi S.A           2016.0
# 27                                 Ucsa S.A.           2015.0
# 28            CORSAN CORVIAM CONSTRUCCION SA           2016.0
# 29                       Green Seosa Pbt Ute           2016.0
# ..                                       ...              ...
# 961                                      NaN              NaN
# 962                                      NaN              NaN
# 963                                      NaN              NaN
# 964                                      NaN              NaN
# 965                                      NaN              NaN
# 966                                      NaN              NaN
# 967                                      NaN              NaN
# 968                                      NaN              NaN
# 969                                      NaN              NaN
# 970                                      NaN              NaN
# 971                                      NaN              NaN
# 972                                      NaN              NaN
# 973                                      NaN              NaN
# 974                                      NaN              NaN
# 975                                      NaN              NaN
# 976                                      NaN              NaN
# 977                                Parquizar              NaN
# 978                                      NaN              NaN
# 979                                      NaN              NaN
# 980                                Parquizar              NaN
# 981                                      NaN              NaN
# 982                                      NaN              NaN
# 983                                      NaN              NaN
# 984                                      NaN              NaN
# 985                                      NaN              NaN
# 986                                      NaN              NaN
# 987                                      NaN              NaN
# 988                                      NaN              NaN
# 989                                      NaN              NaN
# 990                                      NaN              NaN
#
#      cuit_contratista     año
# 0        3.050545e+10  2016.0
# 1        3.070743e+10  2016.0
# 2        3.057845e+10  2017.0
# 3        3.060437e+10  2017.0
# 4        3.064773e+10  2015.0
# 5        3.071497e+10  2017.0
# 6        3.054107e+10  2017.0
# 7        3.351629e+10  2017.0
# 8        3.050545e+10  2018.0
# 9        3.351629e+10  2017.0
# 10       3.050545e+10  2017.0
# 11       3.061575e+10  2017.0
# 12       3.061090e+10  2017.0
# 13       3.055343e+10  2017.0
# 14       3.370729e+10  2017.0
# 15       3.051270e+10  2017.0
# 16       3.062387e+10  2018.0
# 17       3.061090e+10  2017.0
# 18       3.050545e+10  2018.0
# 19       3.350460e+10  2018.0
# 20       3.358817e+10  2018.0
# 21       3.067779e+10  2017.0
# 22       3.071129e+10  2018.0
# 23       3.071149e+10  2017.0
# 24       3.050545e+10  2018.0
# 25       3.071129e+10  2018.0
# 26       3.061575e+10  2017.0
# 27       3.071149e+10  2018.0
# 28       3.071022e+10  2019.0
# 29       3.071547e+10  2019.0
# ..                ...     ...
# 961               NaN  2019.0
# 962               NaN  2018.0
# 963               NaN  2019.0
# 964               NaN  2019.0
# 965               NaN  2019.0
# 966               NaN  2019.0
# 967               NaN  2016.0
# 968               NaN  2016.0
# 969               NaN  2019.0
# 970               NaN  2019.0
# 971               NaN  2019.0
# 972               NaN  2018.0
# 973               NaN  2018.0
# 974               NaN  2018.0
# 975               NaN  2019.0
# 976               NaN  2018.0
# 977               NaN  2019.0
# 978               NaN  2019.0
# 979               NaN  2019.0
# 980               NaN     NaN
# 981               NaN  2019.0
# 982               NaN  2019.0
# 983               NaN  2019.0
# 984               NaN  2020.0
# 985               NaN  2019.0
# 986               NaN  2020.0
# 987               NaN  2019.0
# 988               NaN  2020.0
# 989               NaN  2020.0
# 990               NaN  2019.0
#
# [991 rows x 20 columns]

# %%
print("\n\n\n\n                                             NOS FALTA CALCULAR CANTIDAD DE OBRAS  \n\n\n  ")
# Out:
#                                              NOS FALTA CALCULAR CANTIDAD DE OBRAS

# %%
print("\n\n\n\n                                                   POR BARRIO  \n\n\n  ")
# Out:
#                                                    POR BARRIO

# %%
#cuánto fue el gasto total en obras por barrio


print(obras.groupby(["barrio"]).sum()["monto_contrato"])
# Out:
# barrio
# Agronomía            1.375852e+08
# Almagro              3.512850e+08
# Balvanera            8.069430e+08
# Barracas             1.620409e+09
# Belgrano             5.200217e+09
# Boca                 9.406741e+07
# Boedo                8.430029e+07
# Caballito            1.941864e+08
# Chacarita            1.689598e+09
# Coghlan              7.910862e+07
# Colegiales           2.473005e+07
# Constitución         2.059908e+08
# Flores               5.058089e+08
# Floresta             8.159801e+07
# La Boca              2.531783e+09
# Liniers              2.044951e+08
# Mataderos            4.284640e+08
# Monserrat            3.885665e+07
# Monte Castro         2.067031e+08
# Montserrat           5.213804e+08
# Nueva Pompeya        4.190496e+08
# Nuñez                4.128898e+07
# Palermo              6.133530e+08
# Parque Avellaneda    5.105403e+08
# Parque Chacabuco     6.160064e+07
# Parque Chas          5.360120e+06
# Parque Patricios     3.650338e+08
# Paternal             1.511517e+08
# Puerto Madero        6.429591e+09
# Recoleta             3.171897e+09
# Retiro               4.229324e+09
# Saavedra             2.266507e+08
# San Cristóbal        9.421568e+06
# San Nicolás          1.582785e+09
# San Telmo            1.096116e+08
# Versalles            1.481400e+07
# Villa Crespo         3.127159e+09
# Villa Del Parque     2.016608e+08
# Villa Devoto         2.221545e+08
# Villa Gral. Mitre    6.471353e+06
# Villa Lugano         5.628439e+09
# Villa Luro           2.506559e+07
# Villa Pueyrredon     1.219643e+08
# Villa Real           3.010169e+07
# Villa Riachuelo      2.702700e+08
# Villa Santa Rita     5.600000e+06
# Villa Soldati        2.529939e+09
# Villa Urquiza        3.985025e+08
# Villa del Parque     2.120100e+06
# Vélez Sarsfield      2.521877e+08
# Name: monto_contrato, dtype: float64

# %%
(obras.groupby(["barrio"]).sum()["monto_contrato"]).plot()
#obras.plot(x="barrio", y="monto_contrato",style="o")
#obras.xlabel("barrio")
#obras.ylabel("monto_contrato") ##ajusta parámetros en el eje x e y respectimantemete

# %%
#cuánto fue el gasto medio total en obras por barrio


obras.groupby(["barrio"]).mean()["monto_contrato"]
# Out:
# barrio
# Agronomía            3.439630e+07
# Almagro              2.927375e+07
# Balvanera            2.241508e+07
# Barracas             3.375853e+07
# Belgrano             4.727470e+08
# Boca                 9.406741e+07
# Boedo                1.053754e+07
# Caballito            7.192090e+06
# Chacarita            8.892622e+07
# Coghlan              1.318477e+07
# Colegiales           4.946010e+06
# Constitución         1.872644e+07
# Flores               1.296946e+07
# Floresta             9.066446e+06
# La Boca              7.032730e+07
# Liniers              1.460679e+07
# Mataderos            3.295877e+07
# Monserrat            1.295222e+07
# Monte Castro         2.067031e+07
# Montserrat           2.896558e+07
# Nueva Pompeya        2.993211e+07
# Nuñez                8.257797e+06
# Palermo              1.022255e+07
# Parque Avellaneda    2.320638e+07
# Parque Chacabuco     6.160064e+06
# Parque Chas          2.680060e+06
# Parque Patricios     1.460135e+07
# Paternal             2.159310e+07
# Puerto Madero        8.036989e+08
# Recoleta             1.174777e+08
# Retiro               8.133316e+07
# Saavedra             3.237867e+07
# San Cristóbal        2.355392e+06
# San Nicolás          4.655251e+07
# San Telmo            1.565879e+07
# Versalles            4.938002e+06
# Villa Crespo         6.254319e+08
# Villa Del Parque     2.520759e+07
# Villa Devoto         1.851287e+07
# Villa Gral. Mitre    3.235676e+06
# Villa Lugano         8.400656e+07
# Villa Luro           3.580799e+06
# Villa Pueyrredon     4.065477e+07
# Villa Real           1.003390e+07
# Villa Riachuelo      6.930000e+06
# Villa Santa Rita     5.600000e+06
# Villa Soldati        2.529939e+07
# Villa Urquiza        2.846446e+07
# Villa del Parque     2.120100e+06
# Vélez Sarsfield      4.203128e+07
# Name: monto_contrato, dtype: float64

# %%
(obras.groupby(["barrio"]).mean()["monto_contrato"]).plot()

# %%
print("\n\n\n\n                                             POR ÁREA RESPONSABLE  \n\n\n  ")
# Out:
#                                              POR ÁREA RESPONSABLE

# %%
#cuánto fue el gasto total en obras por área responsable


obras.groupby(["area_responsable"]).sum()["monto_contrato"]
# Out:
# area_responsable
# Corporación Buenos Aires Sur                             4.193583e+08
# Instituto de la Vivienda                                 7.320520e+09
# Ministerio de Ambiente y Espacio Público                 3.518510e+09
# Ministerio de Cultura                                    6.697976e+06
# Ministerio de Desarrollo Humano y Hábitat                3.565323e+08
# Ministerio de Desarrollo Urbano y Transporte             2.678898e+10
# Ministerio de Educación e Innovación                     2.203634e+09
# Ministerio de Justicia y Seguridad                       3.962776e+08
# Ministerio de Salud                                      2.052311e+09
# Secretaría de Integración Social y Urbana - Barrio 31    3.531858e+09
# Subsecretaría de Gestión Comunal                         2.633033e+08
# Name: monto_contrato, dtype: float64

# %%
# Genero nuevo archivo

(obras.groupby(["area_responsable"]).sum()["monto_contrato"]).to_csv("monto_total_por_area.csv", header= "area_responsable")

# %%
#Importo el archivo

monto_t_a = pd.read_csv ("monto_total_por_area.csv", delimiter = ",")

# %%
#Grafico

monto_t_a.plot("area_responsable", "monto_contrato", kind= "bar", figsize= (20, 5))

# %%
#cuánto fue el gasto medio total en obras por área responsable


obras.groupby(["area_responsable"]).mean()["monto_contrato"]
# Out:
# area_responsable
# Corporación Buenos Aires Sur                             3.038829e+06
# Instituto de la Vivienda                                 2.153094e+08
# Ministerio de Ambiente y Espacio Público                 1.861646e+07
# Ministerio de Cultura                                    1.339595e+06
# Ministerio de Desarrollo Humano y Hábitat                1.188441e+07
# Ministerio de Desarrollo Urbano y Transporte             2.092889e+08
# Ministerio de Educación e Innovación                     1.184749e+07
# Ministerio de Justicia y Seguridad                       2.331045e+07
# Ministerio de Salud                                      2.255287e+07
# Secretaría de Integración Social y Urbana - Barrio 31    1.103706e+08
# Subsecretaría de Gestión Comunal                         6.929034e+06
# Name: monto_contrato, dtype: float64

# %%
# Genero nuevo archivo

(obras.groupby(["area_responsable"]).mean()["monto_contrato"]).to_csv("monto_medio_por_area.csv", header= "area_responsable")

# %%
#Importo el archivo

monto_m_a = pd.read_csv ("monto_medio_por_area.csv", delimiter = ",")

# %%
#Grafico

monto_m_a.plot("area_responsable", "monto_contrato", kind= "bar", figsize= (15, 5))

# %%
print("\n\n\n\n                                                 POR TIPO DE OBRA  \n\n\n  ")
# Out:
#                                                  POR TIPO DE OBRA

# %%
obras.groupby(["tipo"]).sum()["monto_contrato"]
# Out:
# tipo
# Arquitectura                    4.024298e+09
# Escuelas                        2.968487e+09
# Espacio Público                 5.444693e+09
# Hidráulica e Infraestructura    5.593732e+09
# Salud                           2.066357e+09
# Transporte                      1.683869e+10
# Vivienda                        9.921724e+09
# Name: monto_contrato, dtype: float64

# %%
# Acá gráfico

# %%
print("\n\n\n\n                                                   POR COMUNA  \n\n\n  ")
# Out:
#                                                    POR COMUNA

# %%
#cuánto fue el gasto total en obras por comuna


obras.groupby(["comuna"]).sum()["monto_contrato"]
# Out:
# comuna
# 1.0     1.474229e+10
# 2.0     3.171897e+09
# 3.0     8.163645e+08
# 4.0     3.405591e+09
# 5.0     2.237021e+08
# 6.0     1.941864e+08
# 7.0     5.674096e+08
# 8.0     9.201395e+09
# 9.0     1.143395e+09
# 10.0    6.104701e+08
# 11.0    6.498899e+08
# 12.0    8.262261e+08
# 13.0    5.316422e+09
# 14.0    6.111680e+08
# 15.0    5.110855e+09
# Name: monto_contrato, dtype: float64

# %%
# Me cuesta trabajar con los resultados de los datos agrupados
# Me genero un nuevo archivo


(obras.groupby(["comuna"]).sum()["monto_contrato"]).to_csv("monto_total_por_comuna.csv", header= "comuna")

# Me pide que ponga un "header", pruebo con comuna y se corrige. Sino usaba los datos de comuna 1 como nombres de las columnas

# %%
#Importo el archivo
monto = pd.read_csv ('monto_total_por_comuna.csv', delimiter = ",")

# %%
# Veo si quedó bien


monto.head(15)
# Out:
#     comuna  monto_contrato
# 0      1.0    1.474229e+10
# 1      2.0    3.171897e+09
# 2      3.0    8.163645e+08
# 3      4.0    3.405591e+09
# 4      5.0    2.237021e+08
# 5      6.0    1.941864e+08
# 6      7.0    5.674096e+08
# 7      8.0    9.201395e+09
# 8      9.0    1.143395e+09
# 9     10.0    6.104701e+08
# 10    11.0    6.498899e+08
# 11    12.0    8.262261e+08
# 12    13.0    5.316422e+09
# 13    14.0    6.111680e+08
# 14    15.0    5.110855e+09

# %%
print("\n\n\n\n\n                                         ESTE DA BIEN!!!!!!!\n\n\n")

# ok, es feo, pero da 


monto.plot("comuna", "monto_contrato", kind= "bar", figsize= (15, 5))
# Out:
#                                          ESTE DA BIEN!!!!!!!

# %%
#cuánto fue el gasto medio total en obras por comuna

obras.groupby(["comuna"]).mean()["monto_contrato"]
# Out:
# comuna
# 1.0     1.100171e+08
# 2.0     1.174777e+08
# 3.0     2.040911e+07
# 4.0     2.768773e+07
# 5.0     1.177379e+07
# 6.0     7.192090e+06
# 7.0     1.157979e+07
# 8.0     4.423747e+07
# 9.0     2.382072e+07
# 10.0    1.606500e+07
# 11.0    2.599560e+07
# 12.0    2.754087e+07
# 13.0    2.311488e+08
# 14.0    1.035878e+07
# 15.0    1.381312e+08
# Name: monto_contrato, dtype: float64

# %%
# Gráfico

# %%
print("\n\n\n\n                                             POR COMUNA Y TIPO DE OBRA  \n\n\n  ")
# Out:
#                                              POR COMUNA Y TIPO DE OBRA

# %%
obras.groupby(["comuna", "tipo"]).sum()["monto_contrato"]
# Out:
# comuna  tipo
# 1.0     Arquitectura                    4.643765e+08
#         Escuelas                        1.202139e+09
#         Espacio Público                 1.890317e+09
#         Hidráulica e Infraestructura    8.993523e+08
#         Salud                           1.595413e+06
#         Transporte                      7.120296e+09
#         Vivienda                        3.164217e+09
# 2.0     Arquitectura                    4.415628e+08
#         Escuelas                        3.030840e+06
#         Espacio Público                 1.197462e+08
#         Hidráulica e Infraestructura    7.536861e+07
#         Salud                           3.051884e+08
#         Transporte                      2.227000e+09
# 3.0     Arquitectura                    1.399498e+08
#         Escuelas                        5.727105e+07
#         Espacio Público                 4.437599e+08
#         Salud                           1.753837e+08
# 4.0     Arquitectura                    3.240957e+08
#         Escuelas                        1.372701e+08
#         Espacio Público                 3.766365e+08
#         Hidráulica e Infraestructura    6.141754e+08
#         Salud                           4.531608e+08
#         Vivienda                        1.500252e+09
# 5.0     Arquitectura                    1.999016e+06
#         Escuelas                        1.944631e+07
#         Espacio Público                 1.947673e+08
#         Salud                           7.489486e+06
# 6.0     Escuelas                        4.291534e+07
#         Espacio Público                 6.026819e+07
#         Salud                           9.100290e+07
#                                             ...
# 11.0    Arquitectura                    4.025249e+06
#         Escuelas                        8.059392e+07
#         Espacio Público                 2.621076e+08
#         Salud                           1.682431e+07
#         Transporte                      2.863388e+08
# 12.0    Arquitectura                    2.385498e+08
#         Escuelas                        1.342337e+08
#         Espacio Público                 9.343932e+07
#         Hidráulica e Infraestructura    6.513665e+07
#         Salud                           4.028932e+06
#         Transporte                      2.394600e+08
#         Vivienda                        5.137767e+07
# 13.0    Arquitectura                    1.593769e+07
#         Escuelas                        2.246844e+07
#         Espacio Público                 1.199186e+08
#         Hidráulica e Infraestructura    2.913475e+09
#         Salud                           4.800000e+07
#         Transporte                      2.196621e+09
# 14.0    Arquitectura                    2.140667e+08
#         Escuelas                        2.250574e+07
#         Espacio Público                 2.648817e+08
#         Salud                           3.788999e+07
#         Transporte                      7.182385e+07
# 15.0    Arquitectura                    5.893734e+07
#         Escuelas                        6.760907e+07
#         Espacio Público                 1.216994e+08
#         Hidráulica e Infraestructura    2.168332e+08
#         Salud                           1.244581e+08
#         Transporte                      3.320582e+09
#         Vivienda                        1.200736e+09
# Name: monto_contrato, Length: 84, dtype: float64

# %%
# Me armo un nuevo archivo

(obras.groupby(["comuna", "tipo"]).sum()["monto_contrato"]).to_csv("monto_total_por_comuna_tipo.csv", header= "comuna")

# %%
monto_t_c_t = pd.read_csv ("monto_total_por_comuna_tipo.csv", delimiter = ",")

# %%
monto_t_c_t.head()
# Out:
#    comuna                          tipo  monto_contrato
# 0     1.0                  Arquitectura    4.643765e+08
# 1     1.0                      Escuelas    1.202139e+09
# 2     1.0               Espacio Público    1.890317e+09
# 3     1.0  Hidráulica e Infraestructura    8.993523e+08
# 4     1.0                         Salud    1.595413e+06

# %%
# ASÍ NO!!



monto.plot("comuna", "monto_contrato", kind= "bar", figsize= (15, 5))

# %%
print("\n\n\n\n                                               SEPARO POR AÑO  \n\n\n  ")
# Out:
#                                                SEPARO POR AÑO

# %%
#Quiero separar los datos anteriores por años


obras['fecha_fin_inicial'] = pd.to_datetime(obras['fecha_fin_inicial'], format="%d/%m/%Y")

# No sé si esto es necesario porque cuando miré la columna apenas habiendo importado el archivo se veía igual

# %%
obras["fecha_fin_inicial"]
# Out:
# 0     2016-05-31
# 1     2016-07-15
# 2     2017-11-15
# 3     2017-02-28
# 4     2015-12-20
# 5     2017-08-30
# 6     2017-10-15
# 7     2017-08-30
# 8     2018-02-15
# 9     2017-09-30
# 10    2017-08-30
# 11    2017-10-31
# 12    2017-11-15
# 13    2017-12-31
# 14    2017-12-20
# 15    2017-03-30
# 16    2018-04-16
# 17    2017-12-31
# 18    2018-12-01
# 19    2018-10-30
# 20    2018-06-30
# 21    2017-01-11
# 22    2018-03-01
# 23    2017-06-30
# 24    2018-06-30
# 25    2018-05-30
# 26    2017-11-15
# 27    2018-01-31
# 28    2019-08-30
# 29    2019-04-30
#          ...
# 961   2019-03-30
# 962   2018-08-01
# 963   2019-05-30
# 964   2019-05-12
# 965   2019-05-30
# 966   2019-01-20
# 967   2016-10-30
# 968   2016-10-30
# 969   2019-02-28
# 970   2019-02-28
# 971   2019-02-28
# 972   2018-12-31
# 973   2018-12-31
# 974   2018-09-28
# 975   2019-07-02
# 976   2018-11-21
# 977   2019-08-15
# 978   2019-05-09
# 979   2019-09-15
# 980          NaT
# 981   2019-06-10
# 982   2019-11-07
# 983   2019-11-13
# 984   2020-02-15
# 985   2019-04-12
# 986   2020-04-27
# 987   2019-08-31
# 988   2020-04-27
# 989   2020-03-02
# 990   2019-06-21
# Name: fecha_fin_inicial, Length: 991, dtype: datetime64[ns]

# %%
# No creo que sea la mejor forma, pero quiero conservar solamente el año de finalización de las obras
# No me interesan día ni mes


for i in obras['fecha_fin_inicial']:
    año = i.year
    print(año)
# Out:
# 2016
# 2016
# 2017
# 2017
# 2015
# 2017
# 2017
# 2017
# 2018
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 
# 2019
# 2019
# 2019
# 2019
# 2016
# 2016
# 2019
# 2019
# 2019
# 2018
# 2018
# 2018
# 2019
# 2018
# 2019
# 2019
# 2019
# nan
# 2019
# 2019
# 2019
# 2020
# 2019
# 2020
# 2019
# 2020
# 2020
# 2019

# %%
#Veo si de esta forma me queda mejor


for i in obras['fecha_fin_inicial']:
    #año = i.year
    año = pd.Series([i.year])
    print(año)
    
# No, fue peor
# Out:
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2015
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2019
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2017
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2021
# dtype: int64
# 0    2019
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2020
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2020
# dtype: int64
# 0    2016
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2019
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2015
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2018
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2018
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2015
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2019
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2015
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2020
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2021
# dtype: int64
# 0    2020
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2020
# dtype: int64
# 0    2020
# dtype: int64
# 0    2019
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2019
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2019
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2019
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2019
# dtype: int64
# 0    2017
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2019
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2019
# dtype: int64
# 0    2017
# dtype: int64
# 0    2019
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2017
# dtype: int64
# 0    2015
# dtype: int64
# 0    2015
# dtype: int64
# 0    2015
# dtype: int64
# 0    2015
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0   NaN
# dtype: float64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2016
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2016
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2020
# dtype: int64
# 0    2021
# dtype: int64
# 0    2017
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2015
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0   NaN
# dtype: float64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2019
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2017
# dtype: int64
# 0    2017
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2020
# dtype: int64
# 0    2020
# dtype: int64
# 0    2020
# dtype: int64
# 0    2020
# dtype: int64
# 0    2019
# dtype: int64
# 0    2020
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2020
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2016
# dtype: int64
# 0    2016
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2018
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0   NaN
# dtype: float64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2019
# dtype: int64
# 0    2020
# dtype: int64
# 0    2019
# dtype: int64
# 0    2020
# dtype: int64
# 0    2019
# dtype: int64
# 0    2020
# dtype: int64
# 0    2020
# dtype: int64
# 0    2019
# dtype: int64

# %%
# Otro intento:
año1= []
for i in obras['fecha_fin_inicial']:
    año = i.year
    año1.append(año)
print (año1)
# Out:
# [2016, 2016, 2017, 2017, 2015, 2017, 2017, 2017, 2018, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2018, 2017, 2018, 2018, 2018, 2017, 2018, 2017, 2018, 2018, 2017, 2018, 2019, 2019, 2019, 2018, 2018, 2017, 2016, 2017, 2016, 2016, 2017, 2018, 2017, 2017, 2017, 2016, 2018, 2017, 2018, 2018, 2017, 2017, 2016, 2016, 2017, 2016, 2017, 2016, 2017, 2017, 2016, 2016, 2017, 2019, 2017, 2018, 2017, 2017, 2018, 2017, 2017, 2016, 2016, 2016, 2016, 2016, 2017, 2017, 2018, 2017, 2019, 2018, 2016, 2017, 2017, 2017, 2018, 2017, 2017, 2017, 2018, 2018, 2018, 2019, 2017, 2019, 2018, 2019, 2018, 2019, 2019, 2018, 2017, 2018, 2019, 2017, 2017, 2021, 2019, 2017, 2017, 2018, 2018, 2019, 2018, 2018, 2017, 2018, 2018, 2018, 2018, 2018, 2017, 2018, 2017, 2017, 2018, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2018, 
# 2  Se Intervienen Los Tramos Comprendidos Entre L...      36942632.0     1.0
# 3  La Obra Incluye El Tramo Ubicado Entre La Av. ...      26938294.0     1.0
# 4  Demoliciones de las construcciones existentes ...       6990315.0     8.0
#
#           barrio  ... mano_obra  compromiso  destacada ba_elige  \
# 0  Villa Urquiza  ...       NaN         NaN         SI      NaN
# 1  Villa Urquiza  ...        16         NaN        NaN      NaN
# 2     Montserrat  ...        55          SI        NaN      NaN
# 3    San Nicolás  ...        59          SI        NaN      NaN
# 4  Villa Soldati  ...       NaN          SI        NaN      NaN
#
#                                         link_interno  \
# 0  https://www.buenosaires.gob.ar/baobras/54-escu...
# 1  https://www.buenosaires.gob.ar/baobras/Donado-...
# 2  https://www.buenosaires.gob.ar/baobras/area-am...
# 3  https://www.buenosaires.gob.ar/baobras/area-am...
# 4  https://www.buenosaires.gob.ar/baobras/villa-o...
#
#                                      pliego_descarga     expediente-numero  \
# 0  https://buenosaires.gob.ar/areas/planeamiento_...     914412-MDUGC-2013
# 1  https://www.buenosaires.gov.ar/areas/planeamie...          5515928/2014
# 2  https://www.buenosaires.gov.ar/areas/planeamie...                   NaN
# 3  https://www.buenosaires.gov.ar/areas/planeamie...                   NaN
# 4  https://www.buenosaires.gov.ar/areas/planeamie...  13793268/DGPUYA/2014
#
#   estudio_ambiental_descarga financiamiento     año
# 0                        NaN            NaN  2016.0
# 1                        NaN            NaN  2016.0
# 2                        NaN            NaN  2017.0
# 3                        NaN            NaN  2017.0
# 4                        NaN            NaN  2015.0
#
# [5 rows x 37 columns]

# %%
print("\n\n\n\n                                             POR COMUNA POR AÑO  \n\n\n  ")
# Out:
#                                              POR COMUNA POR AÑO

# %%
#Acá gasto anual por comuna

obras.groupby(["comuna","año"]).sum()["monto_contrato"]
# Out:
# comuna  año
# 1.0     2016.0    3.313431e+07
#         2017.0    1.402849e+09
#         2018.0    2.213154e+09
#         2019.0    1.093056e+10
#         2020.0    1.625954e+08
# 2.0     2016.0    1.789700e+07
#         2017.0    3.760444e+08
#         2018.0    2.494990e+09
#         2019.0    1.713609e+08
#         2020.0    1.116047e+08
# 3.0     2016.0    5.976117e+07
#         2017.0    1.555105e+08
#         2018.0    4.065346e+08
#         2019.0    1.945582e+08
# 4.0     2015.0    1.004841e+07
#         2016.0    1.505577e+08
#         2017.0    8.495539e+08
#         2018.0    4.132007e+08
#         2019.0    1.888163e+09
#         2020.0    9.406741e+07
# 5.0     2016.0    5.868243e+06
#         2017.0    1.199638e+08
#         2018.0    9.787002e+07
# 6.0     2016.0    1.176950e+07
#         2017.0    1.144569e+08
#         2018.0    4.499789e+07
#         2019.0    2.296216e+07
# 7.0     2016.0    7.518899e+06
#         2017.0    3.451652e+08
#         2018.0    1.298682e+08
#                       ...
# 10.0    2016.0    2.195514e+06
#         2017.0    9.777690e+07
#         2018.0    1.351871e+08
#         2019.0    1.142481e+08
#         2020.0    0.000000e+00
#         2021.0    2.610625e+08
# 11.0    2016.0    1.119888e+08
#         2017.0    1.336130e+08
#         2018.0    1.844049e+08
#         2019.0    2.198832e+08
#         2020.0    0.000000e+00
#         2021.0    0.000000e+00
# 12.0    2016.0    2.374476e+08
#         2017.0    8.670058e+07
#         2018.0    3.262495e+08
#         2019.0    1.758284e+08
# 13.0    2015.0    0.000000e+00
#         2016.0    7.417870e+07
#         2017.0    2.387723e+08
#         2018.0    5.592548e+06
#         2019.0    4.949878e+09
#         2020.0    4.800000e+07
# 14.0    2016.0    1.073277e+08
#         2017.0    2.871980e+08
#         2018.0    1.332959e+08
#         2019.0    8.334646e+07
# 15.0    2016.0    2.588218e+06
#         2017.0    2.609367e+08
#         2018.0    2.479688e+08
#         2019.0    4.599361e+09
# Name: monto_contrato, Length: 73, dtype: float64

# %%
#Acá cantidad de obras por año por comuna

# %%
#etc

# %%
#Cosas que intenté antes y no me dieron resultado (1)
# No entiendo por qué no da error y devuelve eso vacío

obras[obras["fecha_fin_inicial"] == ("%Y, %m, %d == 2019, 06, 21")]
# Out:
# Empty DataFrame
# Columns: [id, entorno, nombre, etapa, tipo, area_responsable, descripcion, monto_contrato, comuna, barrio, direccion, lat, lng, fecha_inicio, fecha_fin_inicial, plazo_meses, porcentaje_avance, imagen_1, imagen_2, imagen_3, imagen_4, licitacion_oferta_empresa, licitacion_anio, contratacion_tipo, nro_contratacion, cuit_contratista, beneficiarios, mano_obra, compromiso, destacada, ba_elige, link_interno, pliego_descarga, expediente-numero, estudio_ambiental_descarga, financiamiento, año]
# Index: []
#
# [0 rows x 37 columns]

# %%
#Cosas que intenté antes y no me dieron resultado (2)


obras[obras["fecha_fin_inicial"] == ("%Y == 2019")]
# Out:
# Empty DataFrame
# Columns: [id, entorno, nombre, etapa, tipo, area_responsable, descripcion, monto_contrato, comuna, barrio, direccion, lat, lng, fecha_inicio, fecha_fin_inicial, plazo_meses, porcentaje_avance, imagen_1, imagen_2, imagen_3, imagen_4, licitacion_oferta_empresa, licitacion_anio, contratacion_tipo, nro_contratacion, cuit_contratista, beneficiarios, mano_obra, compromiso, destacada, ba_elige, link_interno, pliego_descarga, expediente-numero, estudio_ambiental_descarga, financiamiento, año]
# Index: []
#
# [0 rows x 37 columns]

# %%
#Cosas que intenté antes y no me dieron resultado (3)


obras[obras["fecha_fin_inicial"] == "2019-%m-%d "]
# Out:
# Empty DataFrame
# Columns: [id, entorno, nombre, etapa, tipo, area_responsable, descripcion, monto_contrato, comuna, barrio, direccion, lat, lng, fecha_inicio, fecha_fin_inicial, plazo_meses, porcentaje_avance, imagen_1, imagen_2, imagen_3, imagen_4, licitacion_oferta_empresa, licitacion_anio, contratacion_tipo, nro_contratacion, cuit_contratista, beneficiarios, mano_obra, compromiso, destacada, ba_elige, link_interno, pliego_descarga, expediente-numero, estudio_ambiental_descarga, financiamiento, año]
# Index: []
#
# [0 rows x 37 columns]

# %%
# intentos fallidos (4)


print("                                     ACÁ TAMPOCO COINCIDEN LOS VALORES CON EL GRÁFICO")


plt.figure(figsize=(15,5))


sns.barplot(x="comuna", y= "monto_contrato", data=obras, palette="Set3")


plt.ylabel("Monto Contrato", size=14)
plt.xlabel("Comuna", size=14)
plt.title("Distribucion del monto de contrato por comuna", size=16, pad=20)
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.grid(False)
plt.show()
plt.show()
# Out:
#                                      ACÁ TAMPOCO COINCIDEN LOS VALORES CON EL GRÁFICO

# %% [markdown]
# ## Clase 3: Comenzando el proyecto

# %% [markdown]
# **Aclaración importante**: Si bien el objetivo de esta notebook es que hagan un analisis exploratorio pensando en ajustar un modelo de machine learning, también es necesario que encaren el analisis exploratorio para observar que información valiosa podría valer la pena mostrar en una página web que les sirva a los usuarios para comprender los datos.

# %% [markdown]
# Ejemplos:
#
# (a) Gráfico mostrando el monto total destinado a cada tipo de obra para cada año reportado.
# (b) Total de dinero invertido para cada tipo de obra para distintas comunas seleccionadas.

# %% [markdown]
# Tener esto en mente les ayudará también a decidir que variables nuevas pueden obtener de las que ya estan para facilitar la visualización posteriormente.

# %% [markdown]
# ### ANALISIS EXPLORATORIO

# %% [markdown]
# Como dijimos en clases anteriores y repasamos en la clase de hoy, una de las primeras cosas que debe realizar un Data Scientist al iniciar un nuevo proyecto es conocer el dataset con el cual va a trabajar. Este paso se conoce como _"Analisis exploratorio de los datos"_.

# %% [markdown]
# Además de obtener que tipo de datos contiene el dataset, estadistica descriptiva, detectar problemas como valores faltantes, establecer que tipo de relación existe entre las distintas variables, también debemos visualizar los datos. Este análisis nos permitira hacernos preguntas que puedan ser contestadas con el dataset como así plantear estrategias para poder resolver problemas presentes en él.

# %% [markdown]
# Este notebook solo les indicara algunos pasos que deben seguir pero la idea es que cada grupo pueda explorar y visualizar libremente el dataset.

# %% [markdown]
# ### 1) Exploración del dataset

# %% [markdown]
# ### 2) Visualización de los datos

# %% [markdown]
# Para poder visualizar los datos y la relación entre las distintas variables, podemos usar dos librerias: `matplotlib` y `seaborn`.

# %% [markdown]
# Documentación:
# - [matplotlib](https://matplotlib.org/3.1.1/contents.html)
# - [seaborn](https://seaborn.pydata.org/)

# %% [markdown]
# - Importa la libreria `matplotlib.pyplot` como `plt`
# - Importa la libreria seaborn como `sns`

# %%
#Importa las librerias matplotlib y seaborn

# %% [markdown]
# Abajo se da algunos ejemplos de distintos graficos que se pueden obtener con estas librerias.

# %%
from sklearn import datasets

# %%
#Obtenemos un dataset de casas en Boston
boston = datasets.load_boston()
columns = boston.feature_names
boston = pd.DataFrame(boston.data)
boston.columns = columns

# %% [markdown]
# #### Histogramas:

# %%
plt.figure()
plt.hist(boston["AGE"], color="#cf7c17", alpha=0.5)
plt.show()

# %% [markdown]
# #### Distplot:

# %%
plt.figure()
sns.distplot(boston["AGE"], color="#5ea88e")
plt.show()

# %% [markdown]
# #### Boxplot:

# %%
plt.figure()
sns.boxplot(x="AGE", data=boston, color="#5ea88e")
plt.show()

# %% [markdown]
# #### Scaterplot:

# %%
plt.figure()
sns.scatterplot(x="LSTAT", y="PTRATIO",data=boston, color="#5ea88f")
plt.show()

# %% [markdown]
# #### Countplot

# %% [markdown]
# Observa como se pueden ajustar la estetica del grafico (Vale para cualquier grafico).

# %%
plt.figure(figsize=(5,3))


sns.countplot(x="RAD", data=boston, palette="Set3")


plt.ylabel("Cantidad", size=14)
plt.xlabel("EDAD", size=14)
plt.title("Distribucion de la variable edad", size=16, pad=25)
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.grid(False)
plt.show()
plt.show()

# %% [markdown]
# **Otros ejemplos de gráficos**: [Ejemplos en Matplotlib](https://matplotlib.org/3.1.0/gallery/index.html) y [Ejemplos en Seaborn](https://seaborn.pydata.org/examples/index.html)

# %% [markdown]
# ### FEATURE ENGINEEING

# %% [markdown]
# Una vez que visualizamos y exploramos el dataset tenemos una idea de como lucen nuestros datos. Es por eso que ahora debemos empezar a preparar nuestros datos para los siguientes pasos según lo que aprendimos de ellos y las preguntas que nos planteamos.

# %% [markdown]
# #### IMPUTACION DE VALORES FALTANTES

# %% [markdown]
# **_¿Algunas de las variables del dataset presenta valores faltantes?_**

# %% [markdown]
# Si es así debemos tomar una decisión acerca de que hacer con ellos. Como manejar estos datos faltantes es un gran desafio.  La mayoría de las veces no queremos eliminar esos valores porque significaría perder información valiosa en otros features.

# %% [markdown]
# **¿Que debo preguntarme al manejar datos faltantes?**
#
# - ¿Quiero conservar la información?
# - ¿Qué tipo de datos tengo en la columna que voy a imputar?
# - ¿Por qué puede ser que tengo los valores faltantes?:
#     - Valores faltantes al azar
#     - Valores faltantes no al azar
# - Si es una variable numerica continua, ¿Que distribución tiene?

# %% [markdown]
# **¿Como decido que hago con los valores faltantes?**
#
# - Entender que no hay una manera _perfecta_ de manejar los valores faltantes.
#
# - Depende de mis datos
#
# - Observar no solo la cantidad de datos faltantes sino también su patrón.
#
# - Estrategias:
#      - **Eliminar los valores**:
#         - Si la recogida de datos no se ha realizado de forma aleatoria introduce sesgo.
#         - En el caso de que haya mucho patrones con datos faltantes, podría reducir considerablemente la cantidad de filas disponibles.
#      - **Eliminación de la variable (columna)**:
#          - Las variables “descartadas” podrían contener información de vital importancia.
#      - **Imputar los valores**:
#         - Sustituir por media o mediana: Solo en variables numericas
#         - Sustituir por valor mas frecuente: Util para variables categoricas
#         - Algoritmo de ML: K-NN (k-nearest neighboors)

# %% [markdown]
# A) Si optan por imputar los datos, pueden hacerlo usando la siguiente función:
#
# `sklearn.impute.SimpleImputer(missing_values=nan, strategy=’mean’, fill_value=None, copy=True, add_indicator=False)`
#
# - **missing_values**: Indica como son representados los valores faltantes (np.nan es el estandard)
# - **strategy**: `mean`, `median`, `most_frequent`, `constant`.
# - **fill_value**: Si uso `constant`, puedo usar `fill_value` para indicar por cuál valor debe ser reemplazado
# - **copy**: Si pongo True, crea una copia de X
# - **add_indicator**: Agrega un indicador para los valores faltantes.
#
#
# [documentación](https://scikit-learn.org/stable/modules/generated/sklearn.impute.SimpleImputer.html#sklearn.impute.SimpleImputer)

# %% [markdown]
# B) Si optan por eliminar los datos, pueden hacerlo usando la siguiente función:
#
# `.dropna(self, axis=0, how='any', thresh=None, subset=None, inplace=False)`
#
# - **axis**: {0, 1}, default 0. 0: Filas, 1: Columnas
# - **how**: {'any', 'all'}, default 'any'. Any: Si hay un valor faltante elimina la columna o fila. All: Si todos los valores de la fila o columna son faltantes, elimina la fila o columna.
# - **subset**: Nombre de filas o columnas donde buscar valores faltantes
# - **inplace**: True modifica el DataFrame original
#
# [documentación](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html)

# %% [markdown]
# #### DETECCION DE OUTLIERS

# %% [markdown]
# - Manera de detectar outliers:
#     - z-score
#         - Considera que todo valor que se aleje mucho de la media=0 es un outlier.
#         - Depende de la media y el desvio estandard para medir la centralidad y dispersión, los cuales son muy afectados por outliers. Si las variables no tiene una distribución normal, termino removiendo muchos outliers del dataset.
#         - No funciona bien en dataset muy pequeños.
#     - Rango Intercuartil:
#         - Es robusto y no es tan sensible a outliers.

# %% [markdown]
# #### DESCUBRIENDO NUEVAS VARIABLES

# %% [markdown]
# - Combinar variables ya presentes que puedan capturar efectos dependientes entre ambos y afectar el resultado:
#     * Sumando o restando variables
#     * Multiplicando o dividiendo variables

# %% [markdown]
# ## HORA DE TOMAR DECISIONES

# %% [markdown]
# Ahora que ya exploraste, procesaste y descubriste relaciones entre las variables creando nuevos atributos, es hora de tomar decisiones. En este proyecto el proximo paso es ajustar un modelo de machine learning. Si bien podemos decidir luego que queremos visualizar algunos de los resultados obtenidos allí, el ajuste del modelo esta pensado para ser independiente de las visualizaciones que aprenderas a hacer en las proximas cuatro clases del curso utilizando `javascript`.

# %% [markdown]
# Es por eso, que deben decidir que visualizaciones les gustaría mostrar para que cuando trabajen en las clases de javascript lo hagan en post de un objetivo claro.

# %% [markdown]
# Anota acá que relaciones o datos les gustaría mostrar:

# %% [markdown]
# ### GUARDANDO EL ARCHIVO PARA LOS SIGUIENTES PASOS Y PARA LA VISUALIZACION FINAL

# %% [markdown]
# Los siguientes pasos que vamos a tomar implican la transformación de los datos presentes en el dataset para un correcto ajuste de un modelo a elección. Para no tener que correr nuevamente todo el código, podemos guardar en un archivo `csv` el dataset tal cual lo tenemos ahora.
#
# 1) **Utiliza la función `.to_csv()` para guardar tu dataset**. Antes de hacerlo chequea la [documentación](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html).

# %%
obras.to_csv()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a029819922db> in <module>
# ----> 1 obras.to_csv()
#
# NameError: name 'obras' is not defined

# %% [markdown]
# 2) Además, como dijimos anteriormente vamos a visualizar los datos usando javascript en las próximas clases. Para facilitar esta tarea necesitamos generar un archivo `JSON` como output. Afortunadamente, pandas tiene la función **`.to_json()`** que podes chequear la documentación [acá](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_json.html?highlight=to_json#pandas.DataFrame.to_json).
#
# Porque es muy importante el formato con el cual guarden esta info les vamos a dar los argumentos que deben usar.

# %% [markdown]
# - **nombre_del_archivo**: a elección
# - **orient**='records'
# - **force_ascii**=False
